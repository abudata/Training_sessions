# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# u'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
plt.plot(3, 2, '.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvasAgg(fig)

ax = fig.add_subplot(111)
ax.plot(3, 2, '.')

canvas.print_png('test.png')

# %%
# %%html
# <img src='test.png' />
# Out:
# <img src='test.png' />

# %%
plt.figure()
plt.plot(3, 2, '.')
ax =plt.gca()
ax.axis([0, 10, 0, 10])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0, 10, 0, 10]

# %%
plt.figure()
plt.plot(1.5, 1.5, 'o')
plt.plot(2, 2, 'o')
plt.plot(2.5, 2.5, 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = plt.gca()
ax.get_children()

# %%
plt.scatter?

# %%
import numpy as np

x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y = x

plt.figure()
plt.scatter(x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np

x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y = x

colors =['green']*(len(x) - 1)
colors.append('red')

plt.figure()
plt.scatter(x, y, s=100, c=colors)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
zip_generator = zip([1, 2, 3, 4, 5], [5, 7, 8, 9, 10])
x, y = zip(*zip_generator)
print(x)
print(y)
# Out:
# (1, 2, 3, 4, 5)
# (5, 7, 8, 9, 10)

# %%
plt.figure()
plt.scatter(x[:2], y[:2], s=100, c='red', label='Abu')
plt.scatter(x[2:], y[2:], s=100, c='blue', label='Alex')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xlabel('Whatever')
plt.ylabel('Power 1')
plt.title('Relationship between Alex and Abu')
plt.legend(loc=0, frameon=False, title='legend')

# %%
plt.legend?

# %%
plt.gca().get_children()

# %%
legend = plt.gca().get_children()[-2]
legend

# %% [markdown]
# # Line charts:

# %%
import numpy as np

linear_data = np.array([1, 2, 3, 4, 5, 6, 7, 8])
q_data = linear_data**2

plt.figure()
plt.plot(linear_data, '-o', q_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
plt.plot([22, 44, 55], '--r')

# %%
plt.xlabel('some data')
plt.ylabel('some othe kind of data')
plt.title('A title')
plt.legend(['first', 'second', 'third'], loc=0)

# %%
plt.fill_between?

# %%
plt.fill_between(range(len(linear_data)), linear_data, q_data, facecolor='blue', alpha='0.25')

# %%
plt.figure()

observation_dates = np.arange('2017-01-01', '2017-01-09', dtype='datetime64[D]')
plt.plot(observation_dates, linear_data, '-o', observation_dates, q_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
import pandas as pd
plt.figure()

observation_dates = np.arange('2017-01-01', '2017-01-09', dtype='datetime64[D]')
observation_dates = list(map(pd.to_datetime, observation_dates))

plt.plot(observation_dates, linear_data, '-o', observation_dates, q_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
x = plt.gca().xaxis

for item in x.get_ticklabels():
    item.set_rotation(45)

# %%
plt.subplots_adjust(bottom = 0.25)
