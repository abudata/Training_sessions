# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib notebook

# %%
plt.subplot?

# %%
plt.figure()
plt.subplot(1, 2, 1)
linear_data = np.array([1, 2, 3, 4, 5, 6, 7, 8])
plt.plot(linear_data, "-o")
# Out:
# <img src="data:image/png;base64,..." width="595.3333333333334">

# %%
q_data = linear_data**2

plt.subplot(1, 2, 2)
plt.plot(q_data, '-o')

# %%
plt.subplot(1, 2, 1)
plt.plot(q_data, '-x')

# %%
plt.figure()
ax1 = plt.subplot(1, 2, 1)
plt.plot(linear_data, '-o')

ax2 = plt.subplot(1, 2, 2, sharey=ax1)
plt.plot(q_data, '-x')
# Out:
# <img src="data:image/png;base64,..." width="595.3333333333334">

# %%
plt.subplot(1, 2, 1) == plt.subplot(121)
# Out:
# True

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, sharex=True, sharey=True)

ax5.plot(linear_data, '-')
# Out:
# <img src="data:image/png;base64,..." width="595.3333333333334">

# %%
for ax in plt.gcf().get_axes():
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_visible(True)

# %%
plt.gcf().canvas.draw()

# %% [markdown]
# # Histogram

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
axs = [ax1, ax2, ax3, ax4]

for n in range(0, len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0, scale=1, size = sample_size)
    axs[n].hist(sample, bins=100)
    axs[n].set_title('n = {}'.format(sample_size))
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="595.3333333333334">

# %%
plt.figure()
Y = np.random.normal(loc=0, scale=1, size=10000)
X = np.random.random(size=10000)
plt.scatter(X, Y)
# Out:
# <img src="data:image/png;base64,..." width="595.3333333333334">

# %%
import matplotlib.gridspec as gridspec

plt.figure()
gspec = gridspec.GridSpec(3, 3)

top_histogram = plt.subplot(gspec[0, 1:])
side_histogram = plt.subplot(gspec[1: , 0])
lower_right = plt.subplot(gspec[1:, 1:])
# Out:
# <img src="data:image/png;base64,..." width="595.3333333333334">

# %%
lower_right.scatter(X, Y)
top_histogram.hist(X, bins =100)
s = side_histogram.hist(Y, bins=100, orientation='horizontal', normed=True)
side_histogram.invert_xaxis()

# %% [markdown]
# # Box and Whisker Plots

# %%
normal_sample = np.random.normal(loc=0, scale=1, size =10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

# %%
df = pd.DataFrame({'normal': normal_sample, 
                  'random': random_sample,
                  'gamma': gamma_sample})

# %%
df.describe()
# Out:
#               gamma        normal        random
# count  10000.000000  10000.000000  10000.000000
# mean       2.011361     -0.007108      0.499735
# std        1.410904      1.017822      0.289214
# min        0.012373     -3.850354      0.000053
# 25%        0.971859     -0.694311      0.250231
# 50%        1.680797     -0.012147      0.502683
# 75%        2.725439      0.676128      0.751529
# max       10.953299      3.807670      0.999902

# %%
df.shape
# Out:
# (10000, 3)

# %%
plt.figure()

test = plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
his = plt.hist(df['gamma'], bins =100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il

plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')

ax2 = mpl_il.inset_axes(plt.gca(), width ='60%', height='40%', loc=2)
ax2.hist(df['gamma'], bins=100)
ax2.margins(x=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax2.yaxis.tick_right()

# %%
plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']])
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'boxes': [<matplotlib.lines.Line2D at 0x1d932edf518>,
#   <matplotlib.lines.Line2D at 0x1d931c20550>,
#   <matplotlib.lines.Line2D at 0x1d933c85390>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d931cadc18>,
#   <matplotlib.lines.Line2D at 0x1d932fc5710>,
#   <matplotlib.lines.Line2D at 0x1d932a71eb8>,
#   <matplotlib.lines.Line2D at 0x1d931c126a0>,
#   <matplotlib.lines.Line2D at 0x1d933c7d9e8>,
#   <matplotlib.lines.Line2D at 0x1d932d47c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d931d3c1d0>,
#   <matplotlib.lines.Line2D at 0x1d935567748>,
#   <matplotlib.lines.Line2D at 0x1d933e86080>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1d932fc5940>,
#   <matplotlib.lines.Line2D at 0x1d931c12978>,
#   <matplotlib.lines.Line2D at 0x1d933e86cf8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1d932edfa58>,
#   <matplotlib.lines.Line2D at 0x1d931cade10>,
#   <matplotlib.lines.Line2D at 0x1d931d7d160>,
#   <matplotlib.lines.Line2D at 0x1d931d56278>,
#   <matplotlib.lines.Line2D at 0x1d933c85cc0>,
#   <matplotlib.lines.Line2D at 0x1d933c7dc88>]}

# %% [markdown]
# # Heatmaps

# %%
plt.figure()
heat = plt.hist2d(X, Y, bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.colorbar()

# %% [markdown]
# # Animations

# %%
import matplotlib.animation as animation
import numpy as np

n = 100
x = np.random.randn(n)

def update(curr):
    if curr == n:
        a.event_soure.stope()
    plt.cla()
    
    bins = np.arange(-4, 4, 0.5)
    plt.hist(x[:curr], bins=bins)
    plt.axis([-4, 4, 0, 30])
    plt.gca().set_title('Sampling the Normal distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n={}'.format(curr), [3, 27])

# %%
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval=100)
# Out:
# <img src="data:image/png;base64,..." width="640">
